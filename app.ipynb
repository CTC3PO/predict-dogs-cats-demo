# %%
# !pip install -Uqq fastai
# !pip install gradio

from fastai.vision.all import *
import gradio as gr

def is_cat(x): return x[0].isupper()
# Out:
# Requirement already satisfied: gradio in ./.venv/lib/python3.13/site-packages (5.44.0)
# Requirement already satisfied: aiofiles<25.0,>=22.0 in ./.venv/lib/python3.13/site-packages (from gradio) (24.1.0)
# Requirement already satisfied: anyio<5.0,>=3.0 in ./.venv/lib/python3.13/site-packages (from gradio) (4.10.0)
# Requirement already satisfied: audioop-lts<1.0 in ./.venv/lib/python3.13/site-packages (from gradio) (0.2.2)
# Requirement already satisfied: brotli>=1.1.0 in ./.venv/lib/python3.13/site-packages (from gradio) (1.1.0)
# Requirement already satisfied: fastapi<1.0,>=0.115.2 in ./.venv/lib/python3.13/site-packages (from gradio) (0.116.1)
# Requirement already satisfied: ffmpy in ./.venv/lib/python3.13/site-packages (from gradio) (0.6.1)
# Requirement already satisfied: gradio-client==1.12.1 in ./.venv/lib/python3.13/site-packages (from gradio) (1.12.1)
# Requirement already satisfied: groovy~=0.1 in ./.venv/lib/python3.13/site-packages (from gradio) (0.1.2)
# Requirement already satisfied: httpx<1.0,>=0.24.1 in ./.venv/lib/python3.13/site-packages (from gradio) (0.28.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.33.5 in ./.venv/lib/python3.13/site-packages (from gradio) (0.34.4)
# Requirement already satisfied: jinja2<4.0 in ./.venv/lib/python3.13/site-packages (from gradio) (3.1.6)
# Requirement already satisfied: markupsafe<4.0,>=2.0 in ./.venv/lib/python3.13/site-packages (from gradio) (3.0.2)
# Requirement already satisfied: numpy<3.0,>=1.0 in ./.venv/lib/python3.13/site-packages (from gradio) (2.3.2)
# Requirement already satisfied: orjson~=3.0 in ./.venv/lib/python3.13/site-packages (from gradio) (3.11.3)
# Requirement already satisfied: packaging in ./.venv/lib/python3.13/site-packages (from gradio) (25.0)
# Requirement already satisfied: pandas<3.0,>=1.0 in ./.venv/lib/python3.13/site-packages (from gradio) (2.3.2)
# Requirement already satisfied: pillow<12.0,>=8.0 in ./.venv/lib/python3.13/site-packages (from gradio) (11.3.0)
# Requirement already satisfied: pydantic<2.12,>=2.0 in ./.venv/lib/python3.13/site-packages (from gradio) (2.11.7)
# Requirement already satisfied: pydub in ./.venv/lib/python3.13/site-packages (from gradio) (0.25.1)
# Requirement already satisfied: python-multipart>=0.0.18 in ./.venv/lib/python3.13/site-packages (from gradio) (0.0.20)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in ./.venv/lib/python3.13/site-packages (from gradio) (6.0.2)
# Requirement already satisfied: ruff>=0.9.3 in ./.venv/lib/python3.13/site-packages (from gradio) (0.12.10)
# Requirement already satisfied: safehttpx<0.2.0,>=0.1.6 in ./.venv/lib/python3.13/site-packages (from gradio) (0.1.6)
# Requirement already satisfied: semantic-version~=2.0 in ./.venv/lib/python3.13/site-packages (from gradio) (2.10.0)
# Requirement already satisfied: starlette<1.0,>=0.40.0 in ./.venv/lib/python3.13/site-packages (from gradio) (0.47.3)
# Requirement already satisfied: tomlkit<0.14.0,>=0.12.0 in ./.venv/lib/python3.13/site-packages (from gradio) (0.13.3)
# Requirement already satisfied: typer<1.0,>=0.12 in ./.venv/lib/python3.13/site-packages (from gradio) (0.16.1)
# Requirement already satisfied: typing-extensions~=4.0 in ./.venv/lib/python3.13/site-packages (from gradio) (4.15.0)
# Requirement already satisfied: uvicorn>=0.14.0 in ./.venv/lib/python3.13/site-packages (from gradio) (0.35.0)
# Requirement already satisfied: fsspec in ./.venv/lib/python3.13/site-packages (from gradio-client==1.12.1->gradio) (2025.7.0)
# Requirement already satisfied: websockets<16.0,>=10.0 in ./.venv/lib/python3.13/site-packages (from gradio-client==1.12.1->gradio) (15.0.1)
# Requirement already satisfied: idna>=2.8 in ./.venv/lib/python3.13/site-packages (from anyio<5.0,>=3.0->gradio) (3.10)
# Requirement already satisfied: sniffio>=1.1 in ./.venv/lib/python3.13/site-packages (from anyio<5.0,>=3.0->gradio) (1.3.1)
# Requirement already satisfied: certifi in ./.venv/lib/python3.13/site-packages (from httpx<1.0,>=0.24.1->gradio) (2025.8.3)
# Requirement already satisfied: httpcore==1.* in ./.venv/lib/python3.13/site-packages (from httpx<1.0,>=0.24.1->gradio) (1.0.9)
# Requirement already satisfied: h11>=0.16 in ./.venv/lib/python3.13/site-packages (from httpcore==1.*->httpx<1.0,>=0.24.1->gradio) (0.16.0)
# Requirement already satisfied: filelock in ./.venv/lib/python3.13/site-packages (from huggingface-hub<1.0,>=0.33.5->gradio) (3.19.1)
# Requirement already satisfied: requests in ./.venv/lib/python3.13/site-packages (from huggingface-hub<1.0,>=0.33.5->gradio) (2.32.5)
# Requirement already satisfied: tqdm>=4.42.1 in ./.venv/lib/python3.13/site-packages (from huggingface-hub<1.0,>=0.33.5->gradio) (4.67.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in ./.venv/lib/python3.13/site-packages (from huggingface-hub<1.0,>=0.33.5->gradio) (1.1.8)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./.venv/lib/python3.13/site-packages (from pandas<3.0,>=1.0->gradio) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in ./.venv/lib/python3.13/site-packages (from pandas<3.0,>=1.0->gradio) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in ./.venv/lib/python3.13/site-packages (from pandas<3.0,>=1.0->gradio) (2025.2)
# Requirement already satisfied: annotated-types>=0.6.0 in ./.venv/lib/python3.13/site-packages (from pydantic<2.12,>=2.0->gradio) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in ./.venv/lib/python3.13/site-packages (from pydantic<2.12,>=2.0->gradio) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in ./.venv/lib/python3.13/site-packages (from pydantic<2.12,>=2.0->gradio) (0.4.1)
# Requirement already satisfied: click>=8.0.0 in ./.venv/lib/python3.13/site-packages (from typer<1.0,>=0.12->gradio) (8.2.1)
# Requirement already satisfied: shellingham>=1.3.0 in ./.venv/lib/python3.13/site-packages (from typer<1.0,>=0.12->gradio) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in ./.venv/lib/python3.13/site-packages (from typer<1.0,>=0.12->gradio) (14.1.0)
# Requirement already satisfied: six>=1.5 in ./.venv/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas<3.0,>=1.0->gradio) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in ./.venv/lib/python3.13/site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in ./.venv/lib/python3.13/site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in ./.venv/lib/python3.13/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0,>=0.12->gradio) (0.1.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in ./.venv/lib/python3.13/site-packages (from requests->huggingface-hub<1.0,>=0.33.5->gradio) (3.4.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./.venv/lib/python3.13/site-packages (from requests->huggingface-hub<1.0,>=0.33.5->gradio) (2.5.0)

# %%
img = PILImage.create('cattledog.jpg')
img.thumbnail((192,192))
img
# Out:
# PILImage mode=RGB size=192x128

# %%
learn = load_learner('model.pkl')
# Out:
# /Users/chautran/Documents/projects/fastaicourse/dogscatsapp/.venv/lib/python3.13/site-packages/fastai/learner.py:455: UserWarning: load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.
# If you only need to load model weights and optimizer state, use the safe `Learner.load` instead.
#   warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")

# %%
learn.predict(img)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00&lt;?]
#     </div>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 learn.predict(img)
#
# File ~/Documents/projects/fastaicourse/dogscatsapp/.venv/lib/python3.13/site-packages/fastai/learner.py:329, in Learner.predict(self, item, rm_type_tfms, with_input)
#     327 def predict(self, item, rm_type_tfms=None, with_input=False):
#     328     dl = self.dls.test_dl([item], rm_type_tfms=rm_type_tfms, num_workers=0)
# --> 329     inp,preds,_,dec_preds = self.get_preds(dl=dl, with_input=True, with_decoded=True)
#     330     i = getattr(self.dls, 'n_inp', -1)
#     331     inp = (inp,) if i==1 else tuplify(inp)
#
# File ~/Documents/projects/fastaicourse/dogscatsapp/.venv/lib/python3.13/site-packages/fastai/learner.py:316, in Learner.get_preds(self, ds_idx, dl, with_input, with_decoded, with_loss, act, inner, reorder, cbs, **kwargs)
#     314 if with_loss: ctx_mgrs.append(self.loss_not_reduced())
#     315 with ContextManagers(ctx_mgrs):
# --> 316     self._do_epoch_validate(dl=dl)
#     317     if act is None: act = getcallable(self.loss_func, 'activation')
#     318     res = cb.all_tensors()
#
# File ~/Documents/projects/fastaicourse/dogscatsapp/.venv/lib/python3.13/site-packages/fastai/learner.py:252, in Learner._do_epoch_validate(self, ds_idx, dl)
#     250 if dl is None: dl = self.dls[ds_idx]
#     251 self.dl = dl
# --> 252 with torch.no_grad(): self._with_events(self.all_batches, 'validate', CancelValidException)
#
# File ~/Documents/projects/fastaicourse/dogscatsapp/.venv/lib/python3.13/site-packages/fastai/learner.py:207, in Learner._with_events(self, f, event_type, ex, final)
#     206 def _with_events(self, f, event_type, ex, final=noop):
# --> 207     try: self(f'before_{event_type}');  f()
#     208     except ex: self(f'after_cancel_{event_type}')
#     209     self(f'after_{event_type}');  final()
#
# File ~/Documents/projects/fastaicourse/dogscatsapp/.venv/lib/python3.13/site-packages/fastai/learner.py:213, in Learner.all_batches(self)
#     211 def all_batches(self):
#     212     self.n_iter = len(self.dl)
# --> 213     for o in enumerate(self.dl): self.one_batch(*o)
#
# File ~/Documents/projects/fastaicourse/dogscatsapp/.venv/lib/python3.13/site-packages/fastai/data/load.py:129, in DataLoader.__iter__(self)
#     127 self.before_iter()
#     128 self.__idxs=self.get_idxs() # called in context of main process (not workers/subprocesses)
# --> 129 for b in _loaders[self.fake_l.num_workers==0](self.fake_l):
#     130     # pin_memory causes tuples to be converted to lists, so convert them back to tuples
#     131     if self.pin_memory and type(b) == list: b = tuple(b)
#     132     if self.device is not None: b = to_device(b, self.device)
#
# File ~/Documents/projects/fastaicourse/dogscatsapp/.venv/lib/python3.13/site-packages/torch/utils/data/dataloader.py:734, in _BaseDataLoaderIter.__next__(self)
#     731 if self._sampler_iter is None:
#     732     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     733     self._reset()  # type: ignore[call-arg]
# --> 734 data = self._next_data()
#     735 self._num_yielded += 1
#     736 if (
#     737     self._dataset_kind == _DatasetKind.Iterable
#     738     and self._IterableDataset_len_called is not None
#     739     and self._num_yielded > self._IterableDataset_len_called
#     740 ):
#
# File ~/Documents/projects/fastaicourse/dogscatsapp/.venv/lib/python3.13/site-packages/torch/utils/data/dataloader.py:790, in _SingleProcessDataLoaderIter._next_data(self)
#     788 def _next_data(self):
#     789     index = self._next_index()  # may raise StopIteration
# --> 790     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     791     if self._pin_memory:
#     792         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File ~/Documents/projects/fastaicourse/dogscatsapp/.venv/lib/python3.13/site-packages/torch/utils/data/_utils/fetch.py:42, in _IterableDatasetFetcher.fetch(self, possibly_batched_index)
#      40         raise StopIteration
#      41 else:
# ---> 42     data = next(self.dataset_iter)
#      43 return self.collate_fn(data)
#
# File ~/Documents/projects/fastaicourse/dogscatsapp/.venv/lib/python3.13/site-packages/fastai/data/load.py:140, in DataLoader.create_batches(self, samps)
#     138 if self.dataset is not None: self.it = iter(self.dataset)
#     139 res = filter(lambda o:o is not None, map(self.do_item, samps))
# --> 140 yield from map(self.do_batch, self.chunkify(res))
#
# File ~/Documents/projects/fastaicourse/dogscatsapp/.venv/lib/python3.13/site-packages/fastcore/basics.py:254, in chunked(it, chunk_sz, drop_last, n_chunks)
#     252 if not isinstance(it, Iterator): it = iter(it)
#     253 while True:
# --> 254     res = list(itertools.islice(it, chunk_sz))
#     255     if res and (len(res)==chunk_sz or not drop_last): yield res
#     256     if len(res)<chunk_sz: return
#
# File ~/Documents/projects/fastaicourse/dogscatsapp/.venv/lib/python3.13/site-packages/fastai/data/load.py:170, in DataLoader.do_item(self, s)
#     169 def do_item(self, s):
# --> 170     try: return self.after_item(self.create_item(s))
#     171     except SkipItemException: return None
#
# File ~/Documents/projects/fastaicourse/dogscatsapp/.venv/lib/python3.13/site-packages/fastai/data/load.py:177, in DataLoader.create_item(self, s)
#     176 def create_item(self, s):
# --> 177     if self.indexed: return self.dataset[s or 0]
#     178     elif s is None:  return next(self.it)
#     179     else: raise IndexError("Cannot index an iterable dataset numerically - must use `None`.")
#
# File ~/Documents/projects/fastaicourse/dogscatsapp/.venv/lib/python3.13/site-packages/fastai/data/core.py:454, in Datasets.__getitem__(self, it)
#     453 def __getitem__(self, it):
# --> 454     res = tuple([tl[it] for tl in self.tls])
#     455     return res if is_indexer(it) else list(zip(*res))
#
# File ~/Documents/projects/fastaicourse/dogscatsapp/.venv/lib/python3.13/site-packages/fastai/data/core.py:413, in TfmdLists.__getitem__(self, idx)
#     411 res = super().__getitem__(idx)
#     412 if self._after_item is None: return res
# --> 413 return self._after_item(res) if is_indexer(idx) else res.map(self._after_item)
#
# File ~/Documents/projects/fastaicourse/dogscatsapp/.venv/lib/python3.13/site-packages/fastai/data/core.py:373, in TfmdLists._after_item(self, o)
# --> 373 def _after_item(self, o): return self.tfms(o)
#
# File ~/Documents/projects/fastaicourse/dogscatsapp/.venv/lib/python3.13/site-packages/fasttransform/transform.py:248, in Pipeline.__call__(self, o)
# --> 248 def __call__(self, o): return compose_tfms(o, tfms=self.fs, split_idx=self.split_idx)
#
# File ~/Documents/projects/fastaicourse/dogscatsapp/.venv/lib/python3.13/site-packages/fasttransform/transform.py:197, in compose_tfms(x, tfms, is_enc, reverse, **kwargs)
#     195 for f in tfms:
#     196     if not is_enc: f = f.decode
# --> 197     x = f(x, **kwargs)
#     198 return x
#
# File ~/Documents/projects/fastaicourse/dogscatsapp/.venv/lib/python3.13/site-packages/fasttransform/transform.py:114, in Transform.__call__(self, split_idx, *args, **kwargs)
# --> 114 def __call__(self,*args,split_idx=None, **kwargs): return self._call('encodes', *args, split_idx=split_idx, **kwargs)
#
# File ~/Documents/projects/fastaicourse/dogscatsapp/.venv/lib/python3.13/site-packages/fasttransform/transform.py:125, in Transform._call(self, nm, split_idx, *args, **kwargs)
#     123 if split_idx!=self.split_idx and self.split_idx is not None: return args[0]
#     124 if not hasattr(self, nm): return args[0]
# --> 125 return self._do_call(nm, *args, **kwargs)
#
# File ~/Documents/projects/fastaicourse/dogscatsapp/.venv/lib/python3.13/site-packages/fasttransform/transform.py:136, in Transform._do_call(self, nm, *args, **kwargs)
#     134 try: method, ret_type = f._resolve_method_with_cache(f_args)
#     135 except NotFoundLookupError: return x
# --> 136 return retain_type(method(*f_args,**kwargs), x, ret_type)
#
# TypeError: unsupported operand type(s) for +: 'PILImage' and 'dict'

# %%
categories = ('Dog', 'Cat')

def classify_image(img):
    pred,idx,probs = learn.predict(img)
    return dict(zip(categories, map(float,probs)))

# %%
classify_image(img)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00&lt;?]
#     </div>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 classify_image(img)
#
# Cell In[8], line 4, in classify_image(img)
#       3 def classify_image(img):
# ----> 4     pred,idx,probs = learn.predict(img)
#       5     return dict(zip(categories, map(float,probs)))
#
# File ~/Documents/projects/fastaicourse/dogscatsapp/.venv/lib/python3.13/site-packages/fastai/learner.py:329, in Learner.predict(self, item, rm_type_tfms, with_input)
#     327 def predict(self, item, rm_type_tfms=None, with_input=False):
#     328     dl = self.dls.test_dl([item], rm_type_tfms=rm_type_tfms, num_workers=0)
# --> 329     inp,preds,_,dec_preds = self.get_preds(dl=dl, with_input=True, with_decoded=True)
#     330     i = getattr(self.dls, 'n_inp', -1)
#     331     inp = (inp,) if i==1 else tuplify(inp)
#
# File ~/Documents/projects/fastaicourse/dogscatsapp/.venv/lib/python3.13/site-packages/fastai/learner.py:316, in Learner.get_preds(self, ds_idx, dl, with_input, with_decoded, with_loss, act, inner, reorder, cbs, **kwargs)
#     314 if with_loss: ctx_mgrs.append(self.loss_not_reduced())
#     315 with ContextManagers(ctx_mgrs):
# --> 316     self._do_epoch_validate(dl=dl)
#     317     if act is None: act = getcallable(self.loss_func, 'activation')
#     318     res = cb.all_tensors()
#
# File ~/Documents/projects/fastaicourse/dogscatsapp/.venv/lib/python3.13/site-packages/fastai/learner.py:252, in Learner._do_epoch_validate(self, ds_idx, dl)
#     250 if dl is None: dl = self.dls[ds_idx]
#     251 self.dl = dl
# --> 252 with torch.no_grad(): self._with_events(self.all_batches, 'validate', CancelValidException)
#
# File ~/Documents/projects/fastaicourse/dogscatsapp/.venv/lib/python3.13/site-packages/fastai/learner.py:207, in Learner._with_events(self, f, event_type, ex, final)
#     206 def _with_events(self, f, event_type, ex, final=noop):
# --> 207     try: self(f'before_{event_type}');  f()
#     208     except ex: self(f'after_cancel_{event_type}')
#     209     self(f'after_{event_type}');  final()
#
# File ~/Documents/projects/fastaicourse/dogscatsapp/.venv/lib/python3.13/site-packages/fastai/learner.py:213, in Learner.all_batches(self)
#     211 def all_batches(self):
#     212     self.n_iter = len(self.dl)
# --> 213     for o in enumerate(self.dl): self.one_batch(*o)
#
# File ~/Documents/projects/fastaicourse/dogscatsapp/.venv/lib/python3.13/site-packages/fastai/data/load.py:129, in DataLoader.__iter__(self)
#     127 self.before_iter()
#     128 self.__idxs=self.get_idxs() # called in context of main process (not workers/subprocesses)
# --> 129 for b in _loaders[self.fake_l.num_workers==0](self.fake_l):
#     130     # pin_memory causes tuples to be converted to lists, so convert them back to tuples
#     131     if self.pin_memory and type(b) == list: b = tuple(b)
#     132     if self.device is not None: b = to_device(b, self.device)
#
# File ~/Documents/projects/fastaicourse/dogscatsapp/.venv/lib/python3.13/site-packages/torch/utils/data/dataloader.py:734, in _BaseDataLoaderIter.__next__(self)
#     731 if self._sampler_iter is None:
#     732     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     733     self._reset()  # type: ignore[call-arg]
# --> 734 data = self._next_data()
#     735 self._num_yielded += 1
#     736 if (
#     737     self._dataset_kind == _DatasetKind.Iterable
#     738     and self._IterableDataset_len_called is not None
#     739     and self._num_yielded > self._IterableDataset_len_called
#     740 ):
#
# File ~/Documents/projects/fastaicourse/dogscatsapp/.venv/lib/python3.13/site-packages/torch/utils/data/dataloader.py:790, in _SingleProcessDataLoaderIter._next_data(self)
#     788 def _next_data(self):
#     789     index = self._next_index()  # may raise StopIteration
# --> 790     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     791     if self._pin_memory:
#     792         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File ~/Documents/projects/fastaicourse/dogscatsapp/.venv/lib/python3.13/site-packages/torch/utils/data/_utils/fetch.py:42, in _IterableDatasetFetcher.fetch(self, possibly_batched_index)
#      40         raise StopIteration
#      41 else:
# ---> 42     data = next(self.dataset_iter)
#      43 return self.collate_fn(data)
#
# File ~/Documents/projects/fastaicourse/dogscatsapp/.venv/lib/python3.13/site-packages/fastai/data/load.py:140, in DataLoader.create_batches(self, samps)
#     138 if self.dataset is not None: self.it = iter(self.dataset)
#     139 res = filter(lambda o:o is not None, map(self.do_item, samps))
# --> 140 yield from map(self.do_batch, self.chunkify(res))
#
# File ~/Documents/projects/fastaicourse/dogscatsapp/.venv/lib/python3.13/site-packages/fastcore/basics.py:254, in chunked(it, chunk_sz, drop_last, n_chunks)
#     252 if not isinstance(it, Iterator): it = iter(it)
#     253 while True:
# --> 254     res = list(itertools.islice(it, chunk_sz))
#     255     if res and (len(res)==chunk_sz or not drop_last): yield res
#     256     if len(res)<chunk_sz: return
#
# File ~/Documents/projects/fastaicourse/dogscatsapp/.venv/lib/python3.13/site-packages/fastai/data/load.py:170, in DataLoader.do_item(self, s)
#     169 def do_item(self, s):
# --> 170     try: return self.after_item(self.create_item(s))
#     171     except SkipItemException: return None
#
# File ~/Documents/projects/fastaicourse/dogscatsapp/.venv/lib/python3.13/site-packages/fastai/data/load.py:177, in DataLoader.create_item(self, s)
#     176 def create_item(self, s):
# --> 177     if self.indexed: return self.dataset[s or 0]
#     178     elif s is None:  return next(self.it)
#     179     else: raise IndexError("Cannot index an iterable dataset numerically - must use `None`.")
#
# File ~/Documents/projects/fastaicourse/dogscatsapp/.venv/lib/python3.13/site-packages/fastai/data/core.py:454, in Datasets.__getitem__(self, it)
#     453 def __getitem__(self, it):
# --> 454     res = tuple([tl[it] for tl in self.tls])
#     455     return res if is_indexer(it) else list(zip(*res))
#
# File ~/Documents/projects/fastaicourse/dogscatsapp/.venv/lib/python3.13/site-packages/fastai/data/core.py:413, in TfmdLists.__getitem__(self, idx)
#     411 res = super().__getitem__(idx)
#     412 if self._after_item is None: return res
# --> 413 return self._after_item(res) if is_indexer(idx) else res.map(self._after_item)
#
# File ~/Documents/projects/fastaicourse/dogscatsapp/.venv/lib/python3.13/site-packages/fastai/data/core.py:373, in TfmdLists._after_item(self, o)
# --> 373 def _after_item(self, o): return self.tfms(o)
#
# File ~/Documents/projects/fastaicourse/dogscatsapp/.venv/lib/python3.13/site-packages/fasttransform/transform.py:248, in Pipeline.__call__(self, o)
# --> 248 def __call__(self, o): return compose_tfms(o, tfms=self.fs, split_idx=self.split_idx)
#
# File ~/Documents/projects/fastaicourse/dogscatsapp/.venv/lib/python3.13/site-packages/fasttransform/transform.py:197, in compose_tfms(x, tfms, is_enc, reverse, **kwargs)
#     195 for f in tfms:
#     196     if not is_enc: f = f.decode
# --> 197     x = f(x, **kwargs)
#     198 return x
#
# File ~/Documents/projects/fastaicourse/dogscatsapp/.venv/lib/python3.13/site-packages/fasttransform/transform.py:114, in Transform.__call__(self, split_idx, *args, **kwargs)
# --> 114 def __call__(self,*args,split_idx=None, **kwargs): return self._call('encodes', *args, split_idx=split_idx, **kwargs)
#
# File ~/Documents/projects/fastaicourse/dogscatsapp/.venv/lib/python3.13/site-packages/fasttransform/transform.py:125, in Transform._call(self, nm, split_idx, *args, **kwargs)
#     123 if split_idx!=self.split_idx and self.split_idx is not None: return args[0]
#     124 if not hasattr(self, nm): return args[0]
# --> 125 return self._do_call(nm, *args, **kwargs)
#
# File ~/Documents/projects/fastaicourse/dogscatsapp/.venv/lib/python3.13/site-packages/fasttransform/transform.py:136, in Transform._do_call(self, nm, *args, **kwargs)
#     134 try: method, ret_type = f._resolve_method_with_cache(f_args)
#     135 except NotFoundLookupError: return x
# --> 136 return retain_type(method(*f_args,**kwargs), x, ret_type)
#
# TypeError: unsupported operand type(s) for +: 'PILImage' and 'dict'

# %%
image = gr.inputs.Image(shape = (192, 192))
label = gr.outputs.Label()
examples = ['cattledog.jpg', 'tabbycat.jpg']

intf = gr.Interface(fn=classify_image, inputs=image, outputs=label,examples=examples)
intf.launch(inline=False)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 image = gr.inputs.Image(shape = (192, 192))
#       2 label = gr.outputs.Label()
#       3 examples = ['cattledog.jpg', 'tabbycat.jpg']
#
# AttributeError: module 'gradio' has no attribute 'inputs'
